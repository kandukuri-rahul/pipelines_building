# %%
import pandas as pd 
df1=pd.read_csv("C:\\Users\Rahul\\Downloads\\df1_c.csv")
df2=pd.read_csv("C:\\Users\\Rahul\\Downloads\\df2_c.csv")
merged_df=pd.merge(df1,df2,on='customer_id')

# %%
merged_df.duplicated().sum()
merged_df.drop_duplicates()
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#                       phone  \
# 0                       NaN
# 1    001-947-633-4224x07930
# 2     001-869-650-5682x8385
# 3      001-418-931-4146x588
# 4      001-418-931-4146x588
# ...

# %%
def fill_nulls(merged_df):
    for col in merged_df.columns:
        if col=='amount':
            merged_df[col]=merged_df[col].fillna(merged_df['amount'].mean())
        elif merged_df[col].dtype=='object':
            merged_df[col]=merged_df[col].fillna(f'unknown_{col}')
        else :
            merged_df[col]=merged_df[col].fillna(0) 
    return merged_df

cleaned_data=fill_nulls(merged_df)

cleaned_data
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#                       phone  \
# 0             unknown_phone
# 1    001-947-633-4224x07930
# 2     001-869-650-5682x8385
# 3      001-418-931-4146x588
# 4      001-418-931-4146x588
# ...
